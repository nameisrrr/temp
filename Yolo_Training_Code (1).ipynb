# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/Rust
# Out:
# /content/drive/MyDrive/Rust

# %%
import torch

# %%
from IPython.display import Image

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.

# %%
# %cd yolov5
# Out:
# /content/drive/MyDrive/Rust/yolov5

# %%
# !pip install -r requirements.txt

# %%
# %ls
# Out:
# benchmarks.py    detect.py   models/           runs/      tutorial.ipynb
# classify/        export.py   __pycache__/      segment/   utils/
# CONTRIBUTING.md  hubconf.py  README.md         setup.cfg  val.py
# data/            LICENSE     requirements.txt  train.py

# %%
import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 7948654193902211670
#  xla_global_id: -1, name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 13916438528
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 6721143858306801645
#  physical_device_desc: "device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5"
#  xla_global_id: 416903419]

# %%
# !cat /proc/meminfo
# Out:
# MemTotal:       13297228 kB
# MemFree:         7190500 kB
# MemAvailable:   10914264 kB
# Buffers:           66780 kB
# Cached:          3176688 kB
# SwapCached:            0 kB
# Active:           577792 kB
# Inactive:        5164620 kB
# Active(anon):       1000 kB
# Inactive(anon):  1823780 kB
# Active(file):     576792 kB
# Inactive(file):  3340840 kB
# Unevictable:           0 kB
# Mlocked:               0 kB
# SwapTotal:             0 kB
# SwapFree:              0 kB
# Dirty:              1796 kB
# Writeback:             0 kB
# AnonPages:       2498968 kB
# Mapped:           969656 kB
# Shmem:             13576 kB
# KReclaimable:      95168 kB
# Slab:             139760 kB
# SReclaimable:      95168 kB
# SUnreclaim:        44592 kB
# KernelStack:        6304 kB
# PageTables:        18672 kB
# NFS_Unstable:          0 kB
# Bounce:                0 kB
# WritebackTmp:          0 kB
# CommitLimit:     6648612 kB
# Committed_AS:    5739144 kB
# VmallocTotal:   34359738367 kB
# ...

# %%
print('Setup Complete. Using torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# Setup Complete. Using torch 1.12.1+cu113 _CudaDeviceProperties(name='Tesla T4', major=7, minor=5, total_memory=15109MB, multi_processor_count=40)

# %%
# !python train.py --img 640 --batch 16 --epochs 150 --data /content/drive/MyDrive/Rust/dataset.yaml --weights /content/drive/MyDrive/Rust/yolov5m.pt
# Out:
# train: weights=/content/drive/MyDrive/Rust/yolov5m.pt, cfg=, data=/content/drive/MyDrive/Rust/dataset.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=150, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# Command 'git fetch origin' timed out after 5 seconds
# YOLOv5 🚀 v6.2-177-g2373d54 Python-3.7.14 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %%
Image(filename='/content/drive/MyDrive/Rust/rust_img2.png', width=640)

# %%
# !python detect.py --source /content/drive/MyDrive/Rust/rust_img2.png --weights /content/drive/MyDrive/Rust/yolov5/runs/train/exp6/weights/best.pt --img 640
# Out:
# detect: weights=['/content/drive/MyDrive/Rust/yolov5/runs/train/exp6/weights/best.pt'], source=/content/drive/MyDrive/Rust/rust_img2.png, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v6.2-177-g2373d54 Python-3.7.14 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 212 layers, 20856975 parameters, 0 gradients, 47.9 GFLOPs
# image 1/1 /content/drive/MyDrive/Rust/rust_img2.png: 384x640 3 Severes, 22.1ms
# Speed: 0.6ms pre-process, 22.1ms inference, 35.7ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp9

# %%
Image(filename='/content/drive/MyDrive/Rust/yolov5/runs/detect/exp8/rust_img2.png', width=640)
